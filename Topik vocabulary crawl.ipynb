# %%
import pandas as pd
import urllib3
from bs4 import BeautifulSoup

# %%
http = urllib3.PoolManager()
r = http.request('GET', 'https://trilingual.jp/jako/20190416-1632/')
soup = BeautifulSoup(r.data, 'lxml')

# %%
table = soup.find('table', attrs={'class': 'tablepress-id-7'})

# %%
def parse_table(table):
    table_body = table.find('tbody')
    data = []
    rows = table_body.find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele])
    return data

# %%
topik_level_1 = pd.DataFrame(parse_table(table), columns=['index', 'word', 'meaning'])

# %%
topik_level_1.head()
# Out:
#   index word      meaning
# 0     1   가게  store, shop
# 1     2   가격        price
# 2     3   가구    furniture
# 3     4  가깝다        close
# 4     5   가끔    sometimes

# %%
import os

# %%
SOURCE = 'memrise_raw_crawl/'
for name in os.listdir(SOURCE):
    if os.path.isdir(SOURCE+name):
        d = []
        if 'summary.csv' not in os.listdir(SOURCE+name):    
            for filename in os.listdir(SOURCE+name):

                if filename[-4:] == '.csv':
                    print(os.path.join(SOURCE, name, filename))
                    df = pd.read_csv(os.path.join(SOURCE, name, filename), sep='\t', header=None)
                    if df.columns.__len__() != 2 : print(df.columns.__len__())
                    d.append(df)
            if len(d) > 0:
                df = pd.concat(d)
                df.to_csv(os.path.join(SOURCE, name, 'summary.csv'))

# %%
level_1 = ['"Sogang Korean New Series 1A" Vocabulary', 
           '"Sogang Korean New Series 1B" Vocabulary',
           'Integrated Korean Beginning 1', 
           'KIIP Beginner Level 1', 
           'Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어)', 
           'Fun Fun Korean 1', 
           '성균관어학 1급'
          ]

level_2 = ['Integrated Korean Beginning 2', 
           'KIIP Beginner Level 2',
           'Sogang Korean 2A Vocabulary',
           'Sogang Korean 2B (w', 
           'Yonsei Level 2 Vocabulary (연세 한국어 2급 단어)', 
           'Fun Fun Korean 2',
           '성균관 어학 2급'
          ]

level_3 = ['Sogang 3A vocabulary', 
           'Sogang Korean 3B (w',
           'Integrated Korean Intermediate 1', 
           'KIIP 중급1 (Level 3)',
           'Hanyang Workbook - 중급 1',
           'Yonsei 3-1 연세 한국어',
           'Yonsei 3-2 연세 한국어',
           '성균관어학 3급'
          ]

level_4 = ['Integrated Korean Intermediate 2 - First Edition', 
           'KIIP 2016 Level 4 ~ 중급2 NO TYPING', 
           'KIIP 4 - 2016',
           'Sogang 4A', 
           'Sogang 4B', 
           '한양대 중급2', 
           'Seoul National University Korean Level 4', 
           '연세 한국어 4-1 [Yonsei Korean 4-1]',
           'Yonsei Korean 4-2 (Units 6-10) + Proverbs',
           '가나다 intermediate 2',
           '서울대 한국어 4B',
           '성균관 어학 4급'
          ]

level_5 = ['KIIP Level 5 (new book 2016)', 
           '한양대 고급1', 
           'Ewha Korean 5', 
           '서울대 한국어 5A',
           '서울대 5B 한국어 교과서',
           '성균관 어학 5급'
          ]

level_6 = ['서울대 한국어 6A 교과서',
           '한양 고급2']

beginner = ['TOPIK Beginner Vocabulary List', 
            'Yonsei Korean Vocab Beginner', 
            '쏙쏙 40 days TOPIK 초급']

intermediate = ['Korean Vocabulary Practice (INTERMEDIATE)', 
                'TOPIK Essential Vocab 1000 (Intermediate)',
                'TOPIK in 30 Days+ Intermediate Vocabulary',
                'TOPIK 필수어위 1000 중급',
                '쏙쏙 TOPIK 한국어 어휘 중급 (day by day)',
                '2000 Essential Korean Words - Intermediate'
               ]

advanced = ['TOPIK Advanced Vocabulary',
            'Korean Vocabulary Practice for Foreigners Advanced', 
            'New TOPIK II 필수어휘 Vocabulary for Levels 5 & 6', 
            '토픽 어휘로 잡아라! [고급]',
            '한국어 TOPIK 어휘 고급 (50 days) advanced TOPIK vocab'
           ]

# %%
def find_source(filename):
    f = filename.lower()
    if 'sogang' in f:
        return 'sogang'
    elif 'yonsei' in f or '연세' in f:
        return 'yonsei'
    elif '한양' in f or 'hanyang' in f:
        return 'hanyang'
    elif '서울대' in f:
        return 'SNU'
    elif '성균관' in f:
        return 'sungkyunkwan'
    elif 'ewha' in f or '이화'in f:
        return 'ewha'
    elif 'kiip' in f:
        return 'kiip'
    elif 'integrated'in f:
        return 'integrated'
    elif 'topik' in f:
        return 'topik'
    else:
        return 'other'

# %%
frequencies = pd.read_csv('frequency_list.csv', index_col=0)

# %%
frequencies.head()
# Out:
#    word  frequency
# 0   일부러       1903
# 1  시작하다         80
# 2    잡지       1471
# 3   끼우다       2704
# 4    두께       3730

# %%
from wordfreq import zipf_frequency

# %%
def get_full_list(list_):
    d = []
    for filename in list_:
        df = pd.read_csv(os.path.join(SOURCE, filename, 'summary.csv'), index_col=0, names=['ko', 'en'], header=0)
        df['word_count'] = df['ko'].map(lambda x: x.split(' ').__len__())
        df['source'] = find_source(filename)
        df['filepath'] = filename
        df['zipf'] = df.ko.map(lambda x: zipf_frequency(x, 'ko'))
        df = pd.merge(df, frequencies, left_on='ko', right_on='word', how='left')
        d.append(df)
    return pd.concat(d)

# %%
def find_differences(level_1_vocabulary):
    categories = level_1_vocabulary.source.value_counts().index
    categories = sorted(categories)
    for source in categories:
        for source2 in categories:
            if source < source2:
                s = set(level_1_vocabulary[(level_1_vocabulary.source == source) & (level_1_vocabulary.word_count == 1)].ko.to_list())
                s2 = set(level_1_vocabulary[(level_1_vocabulary.source == source2) & (level_1_vocabulary.word_count == 1)].ko.to_list())
                print(source, 'und', source2)
                print('\tdifferent vocabulary', len(s.difference(s2)))
                print('\tsame vocabulary', len(s.intersection(s2)))

# %%
beginner_vocab = pd.concat([get_full_list(beginner), get_full_list(level_1), get_full_list(level_2)])
beginner_vocab['level'] = 'beginner'
beginner_vocab.sort_values(by='zipf', ascending=False).to_csv('beginner.csv')

# %%
intermediate_vocab = pd.concat([get_full_list(intermediate), get_full_list(level_3), get_full_list(level_4)])
intermediate_vocab['level'] = 'intermediate'
intermediate_vocab.sort_values(by='zipf', ascending=False).to_csv('intermediate.csv')

# %%
advanced_vocab = pd.concat([get_full_list(advanced), get_full_list(level_5), get_full_list(level_6)])
advanced_vocab['level'] = 'advanced'
advanced_vocab.sort_values(by='zipf', ascending=False).to_csv('advanced.csv')

# %%
all_vocab = pd.concat([beginner_vocab, intermediate_vocab, advanced_vocab])

# %%
single_word = all_vocab[(all_vocab.word_count == 1)]

# %%
import re

# %%
single_word.ko.map(lambda x: len(re.findall('[\W]', x)) > 0).value_counts()
# Out:
# False    42969
# True       253
# Name: ko, dtype: int64

# %%
single_word[~single_word.ko.map(lambda x: len(re.findall('[\W]', x)) > 0)].ko.value_counts()
# Out:
# 맡다      23
# 쓰다      22
# 바르다     20
# 싸다      20
# 걸리다     20
#         ..
# 남방셔츠     1
# 승리자      1
# 원님       1
# 법무부      1
# 명동       1
# Name: ko, Length: 15291, dtype: int64

# %%
single_word = single_word[~single_word.ko.map(lambda x: len(re.findall('[\W]', x)) > 0)]

# %%
unified_df = single_word.groupby('ko').apply(lambda x: set(x.source.to_list())).reset_index(name='source')

# %%
unified_df = unified_df.merge(
    single_word.groupby('ko').apply(lambda x: list(set(x.en.to_list()))).reset_index(name='translation'),
    on='ko')

# %%
unified_df = unified_df.merge(
    single_word.groupby('ko').apply(lambda x: set(x.level.to_list())).reset_index(name='level'),
    on='ko')

# %%
unified_df = unified_df.merge(
    single_word.groupby('ko').apply(lambda x: set(x.filepath.to_list())).reset_index(name='memerisedeck'),
    on='ko')

# %%
unified_df = unified_df[unified_df.ko.map(lambda x: re.match('^[\d]*$', x) == None)]

# %%
unified_df[unified_df.level.map(lambda x: 'beginner' in x)]
# Out:
#           ko                                             source  \
# 4        1인실                                            {other}
# 6        1주일                                           {sogang}
# 7         1층                                           {yonsei}
# 20       5개월                                           {sogang}
# 24      AS센터                                            {other}
# ...      ...                                                ...
# 15273     흰색  {other, integrated, sungkyunkwan, hanyang, sog...
# 15280      힘                             {topik, yonsei, other}
# 15284    힘내다                                     {topik, other}
# 15285    힘들다         {other, sungkyunkwan, topik, yonsei, kiip}
# 15286  힘들어하다                                            {other}
#
#                                              translation  \
# 4                                          [single room]
# 6                                             [one week]
# 7                                            [1st floor]
# 20                                         [five months]
# 24                          [after-sales service center]
# ...                                                  ...
# 15273                        [White, white, white color]
# 15280  [Strength, strength, energy, power (not 기...),...
# 15284                [to cheer up, pluck up one's heart]
# 15285  [To be tough, to have a hard time, difficult, ...
# 15286                            [to have difficulty in]
#
#                           level  \
# 4                    {beginner}
# 6                    {beginner}
# 7                    {beginner}
# 20                   {beginner}
# 24                   {beginner}
# ...                         ...
# 15273  {intermediate, beginner}
# 15280  {intermediate, beginner}
# 15284  {intermediate, beginner}
# 15285                {beginner}
# 15286                {beginner}
#
#                                             memerisedeck
# 4                                     {Fun Fun Korean 2}
# 6                          {Sogang Korean 2A Vocabulary}
# 7       {Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어)}
# 20                         {Sogang Korean 2A Vocabulary}
# 24                                    {Fun Fun Korean 2}
# ...                                                  ...
# 15273  {Fun Fun Korean 2, 성균관 어학 4급, Sogang 3A vocabu...
# 15280  {쏙쏙 40 days TOPIK 초급, 2000 Essential Korean Wo...
# 15284  {Fun Fun Korean 2, 쏙쏙 TOPIK 한국어 어휘 중급 (day by ...
# 15285  {성균관 어학 2급, Fun Fun Korean 1, KIIP Beginner Le...
# 15286                                 {Fun Fun Korean 2}
#
# [3166 rows x 5 columns]

# %%
unified_df[unified_df.level.map(lambda x: 'intermediate' in x)]
# Out:
#          ko                             source  \
# 2        1등                    {other, sogang}
# 3       1인당                     {yonsei, kiip}
# 5       1인용                           {sogang}
# 8       20쌍                             {kiip}
# 9      20인치                           {sogang}
# ...     ...                                ...
# 15282    힘껏              {topik, sungkyunkwan}
# 15284   힘내다                     {topik, other}
# 15287    힘듦                     {sungkyunkwan}
# 15288   힘쓰다  {topik, other, SNU, sungkyunkwan}
# 15290    힙합                            {other}
#
#                                              translation  \
# 2                                          [first place]
# 3                  [per capita, per person, each person]
# 5                                       [one person use]
# 8                               [20 pairs, couples (스물)]
# 9                                        [twenty inches]
# ...                                                  ...
# 15282  [with all one's strength, With all the force o...
# 15284                [to cheer up, pluck up one's heart]
# 15287                                   [Laboriousness ]
# 15288   [to strive, try hard, strive, To make an effort]
# 15290                                          [hip-hop]
#
#                           level  \
# 2                {intermediate}
# 3                {intermediate}
# 5                {intermediate}
# 8                {intermediate}
# 9                {intermediate}
# ...                         ...
# 15282  {intermediate, advanced}
# 15284  {intermediate, beginner}
# 15287            {intermediate}
# 15288  {intermediate, advanced}
# 15290            {intermediate}
#
#                                             memerisedeck
# 2           {가나다 intermediate 2, Sogang Korean 3B (w}
# 3      {KIIP 2016 Level 4 ~ 중급2 NO TYPING, 연세 한국어 4-1...
# 5                                            {Sogang 4A}
# 8                                   {KIIP 중급1 (Level 3)}
# 9                                  {Sogang Korean 3B (w}
# ...                                                  ...
# 15282  {쏙쏙 TOPIK 한국어 어휘 중급 (day by day), 한국어 TOPIK 어휘...
# 15284  {Fun Fun Korean 2, 쏙쏙 TOPIK 한국어 어휘 중급 (day by ...
# 15287                                        {성균관 어학 4급}
# 15288  {서울대 5B 한국어 교과서, 쏙쏙 TOPIK 한국어 어휘 중급 (day by da...
# 15290         {Seoul National University Korean Level 4}
#
# [9018 rows x 5 columns]

# %%
unified_df = unified_df.merge(frequencies, left_on='ko', right_on='word', how='left')
del unified_df['word']

# %%
unified_df['zipf'] = unified_df.ko.map(lambda x: zipf_frequency(x, 'ko'))

# %%
unified_df = unified_df.sort_values(by='zipf', ascending=False)

# %%
unified_df.head(20)
# Out:
#        ko                                             source  \
# 10326   이  {other, integrated, sungkyunkwan, topik, yonse...
# 10207   을                                          {hanyang}
# 9035    에                                       {integrated}
# 10190   은                                            {other}
# 934     고                                             {kiip}
# 2904    다         {other, integrated, topik, yonsei, sogang}
# 10255   의                 {yonsei, integrated, sungkyunkwan}
# 8846    어                        {other, integrated, sogang}
# 3401    도          {yonsei, other, integrated, sungkyunkwan}
# 3776    들                          {yonsei, integrated, SNU}
# 14238  하고                         {integrated, sungkyunkwan}
# 14336   한    {other, integrated, SNU, yonsei, ewha, hanyang}
# 14252  하다                  {topik, yonsei, kiip, integrated}
# 8404    아                                     {sungkyunkwan}
# 685     게                                            {topik}
# 2364    나          {topik, yonsei, integrated, sungkyunkwan}
# 12275   지                                            {topik}
# 14504   해              {topik, yonsei, sungkyunkwan, sogang}
# 10854  있다           {other, integrated, topik, yonsei, kiip}
# 515     거                                {topik, integrated}
#
#                                              translation  \
# 10326  [2 (Sino-Korean), two, Tooth, tooth, 2, teeth,...
# 10207                  [the weaker person in a contract]
# 9035   [at, in, on (time), to (destination), in, at, ...
# 10190                                           [silver]
# 934    [put in front of someone's name to show they'v...
# 2904                   [all, all, everything (not 전...)]
# 10255     [of (particle), Possessive particle, dash (-)]
# 8846                                           [oh, oh!]
# 3401   [a degree (temperature), Too, also, also, too ...
# 3776                            [plural particle, Field]
# 14238                      [with, and (with nouns), And]
# 14336  [resentment[sorrow regret], approximately (=약)...
# 14252                       [to do, 낚시, 등산, 축구, to play]
# 8404                                            [Ah, oh]
# 685                                             [a crab]
# 2364                       [I (plain), I, me (informal)]
# 12275               [the time since, from the time when]
# 14504  [year, harm/damage (verbs used: 입다, 입히다, 주다), ...
# 10854  [to have/exist, to exist, to be, to have, to b...
# 515                 [thing (contraction), thing (abbr.)]
#
#                                     level  \
# 10326            {intermediate, beginner}
# 10207                          {advanced}
# 9035                           {beginner}
# 10190                      {intermediate}
# 934                            {advanced}
# 2904             {intermediate, beginner}
# 10255                          {beginner}
# 8846                           {beginner}
# 3401             {intermediate, beginner}
# 3776                 {beginner, advanced}
# 14238                          {beginner}
# 14336  {intermediate, beginner, advanced}
# 14252                          {beginner}
# 8404                           {beginner}
# 685                        {intermediate}
# 2364                           {beginner}
# 12275                      {intermediate}
# 14504            {intermediate, beginner}
# 10854                          {beginner}
# 515                            {beginner}
#
#                                             memerisedeck  frequency  zipf
# 10326  {성균관어학 1급, 성균관어학 3급, KIIP Beginner Level 1, 쏙쏙...     5117.0  7.49
# 10207                                           {한양 고급2}        NaN  7.35
# 9035   {Integrated Korean Beginning 1, Integrated Kor...     2725.0  7.22
# 10190       {2000 Essential Korean Words - Intermediate}     4439.0  7.20
# 934                       {KIIP Level 5 (new book 2016)}        NaN  7.17
# 2904   {TOPIK in 30 Days+ Intermediate Vocabulary, Fu...     3271.0  7.11
# 10255  {Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어...        NaN  6.99
# 8846   {Sogang Korean 2B (w, Fun Fun Korean 2, Integr...      331.0  6.98
# 3401   {Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어...     2972.0  6.98
# 3776   {Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어...     2243.0  6.96
# 14238          {성균관어학 1급, Integrated Korean Beginning 1}        NaN  6.94
# 14336  {Fun Fun Korean 2, 서울대 한국어 4B, Integrated Kore...     2922.0  6.91
# 14252  {Integrated Korean Beginning 1, KIIP Beginner ...        1.0  6.91
# 8404                                          {성균관어학 1급}      217.0  6.90
# 685          {TOPIK in 30 Days+ Intermediate Vocabulary}     3547.0  6.90
# 2364   {Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어...        4.0  6.89
# 12275        {TOPIK in 30 Days+ Intermediate Vocabulary}      527.0  6.87
# 14504  {연세 한국어 4-1 [Yonsei Korean 4-1], 성균관 어학 4급, So...     5052.0  6.82
# 10854  {Integrated Korean Beginning 1, Fun Fun Korean...        2.0  6.77
# 515    {Integrated Korean Beginning 1, TOPIK Beginner...     2480.0  6.75

# %%
set(frequencies.word.to_list()).issubset(set(unified_df.ko.to_list()))
# Out:
# False

# %%
frequent_but_not_in_list = set(frequencies.word.to_list()).difference(set(unified_df.ko.to_list()))

# %%
len(frequent_but_not_in_list)
# Out:
# 693

# %%
less_frequent_in_list = (set(unified_df.ko.to_list())).difference(set(frequencies.word.to_list()))

# %%
len(less_frequent_in_list)
# Out:
# 10516

# %%
frequent_but_not_in_list = frequencies[frequencies.word.isin(frequent_but_not_in_list)].copy()

# %%
set('가입자').issubset(set(unified_df.ko.to_list()))
# Out:
# False

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
frequent_but_not_in_list['pos'] = frequent_but_not_in_list.word\
                                    .map(lambda x: okt.pos(x))\
                                    .map(lambda x: ' '.join([y[1] for y in x]))

# %%
frequent_but_not_in_list.pos.value_counts()
# Out:
# Noun                    457
# Verb                     79
# Noun Verb                50
# Adjective                34
# Noun Suffix              23
# Adverb                   22
# Determiner Noun          11
# Noun Josa                 5
# Modifier                  2
# Eomi                      2
# Josa                      1
# Adverb Verb               1
# VerbPrefix Verb           1
# Conjunction               1
# Determiner Noun Verb      1
# Noun Noun                 1
# Verb Noun                 1
# Exclamation               1
# Name: pos, dtype: int64

# %%
frequent_but_not_in_list[frequent_but_not_in_list.pos != 'Noun'].sample(10)
# Out:
#        word  frequency              pos
# 5041    충격적       3646      Noun Suffix
# 694   만들어지다        832             Verb
# 3488    잘살다       4353             Verb
# 738    건설되다       4145        Noun Verb
# 2431    트이다       2117             Verb
# 387    발음하다       5371        Noun Verb
# 3502     저곳       5464  Determiner Noun
# 2311    소중히       4588        Adjective
# 1796      하       4961      Exclamation
# 5189   약해지다       3885             Verb

# %%
unified_df['pos'] = unified_df.ko.map(lambda x: okt.pos(x)).map(lambda x: ' '.join([y[1] for y in x]))

# %%
unified_df.head(10)
# Out:
#       ko                                             source  \
# 10326  이  {other, integrated, sungkyunkwan, topik, yonse...
# 10207  을                                          {hanyang}
# 9035   에                                       {integrated}
# 10190  은                                            {other}
# 934    고                                             {kiip}
# 2904   다         {other, integrated, topik, yonsei, sogang}
# 10255  의                 {yonsei, integrated, sungkyunkwan}
# 8846   어                        {other, integrated, sogang}
# 3401   도          {yonsei, other, integrated, sungkyunkwan}
# 3776   들                          {yonsei, integrated, SNU}
#
#                                              translation  \
# 10326  [2 (Sino-Korean), two, Tooth, tooth, 2, teeth,...
# 10207                  [the weaker person in a contract]
# 9035   [at, in, on (time), to (destination), in, at, ...
# 10190                                           [silver]
# 934    [put in front of someone's name to show they'v...
# 2904                   [all, all, everything (not 전...)]
# 10255     [of (particle), Possessive particle, dash (-)]
# 8846                                           [oh, oh!]
# 3401   [a degree (temperature), Too, also, also, too ...
# 3776                            [plural particle, Field]
#
#                           level  \
# 10326  {intermediate, beginner}
# 10207                {advanced}
# 9035                 {beginner}
# 10190            {intermediate}
# 934                  {advanced}
# 2904   {intermediate, beginner}
# 10255                {beginner}
# 8846                 {beginner}
# 3401   {intermediate, beginner}
# 3776       {beginner, advanced}
#
#                                             memerisedeck  frequency  zipf  \
# 10326  {성균관어학 1급, 성균관어학 3급, KIIP Beginner Level 1, 쏙쏙...     5117.0  7.49
# 10207                                           {한양 고급2}        NaN  7.35
# 9035   {Integrated Korean Beginning 1, Integrated Kor...     2725.0  7.22
# 10190       {2000 Essential Korean Words - Intermediate}     4439.0  7.20
# 934                       {KIIP Level 5 (new book 2016)}        NaN  7.17
# 2904   {TOPIK in 30 Days+ Intermediate Vocabulary, Fu...     3271.0  7.11
# 10255  {Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어...        NaN  6.99
# 8846   {Sogang Korean 2B (w, Fun Fun Korean 2, Integr...      331.0  6.98
# 3401   {Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어...     2972.0  6.98
# 3776   {Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어...     2243.0  6.96
#
#           pos
# 10326    Noun
# 10207    Josa
# 9035     Josa
# 10190    Noun
# 934      Noun
# 2904   Adverb
# 10255    Noun
# 8846     Eomi
# 3401     Noun
# 3776     Verb

# %%
frequent_but_not_in_list[frequent_but_not_in_list.pos == "Determiner Noun Verb"]
# Out:
#       word  frequency                   pos
# 2570  그제서야       3269  Determiner Noun Verb

# %%
frequent_but_not_in_list
# Out:
#       word  frequency        pos
# 12    준비되다       3989  Noun Verb
# 37     조미료       1375       Noun
# 39      도덕       3016       Noun
# 44      크림       3399       Noun
# 52     시리즈       1229       Noun
# ...    ...        ...        ...
# 5407    때로       1059  Noun Josa
# 5426    비상       3959       Noun
# 5438    눈앞       1528       Noun
# 5440   생산력       2274       Noun
# 5456    정지       4049       Noun
#
# [693 rows x 3 columns]

# %%
import urllib.parse
# Out:
# '%ED%81%AC%EB%A6%BC'

# %%
import json
import urllib3
from bs4 import BeautifulSoup

# %%
def get_naver_dict_definition(word):
    STEM = 'http://ac.dict.naver.com/enkodict/ac?st=11001&r_lt=11001&q='
    http = urllib3.PoolManager()
    r = http.request('GET', STEM +word)
    soup = BeautifulSoup(r.data, 'lxml')
    try:
        translation = json.loads(soup.text)['items'][0][0][1][0]
        print(translation)
        return translation
    except:
        return None

# %%
translations = frequent_but_not_in_list.word.map(lambda x: get_naver_dict_definition(x))

# %%
frequent_but_not_in_list['en'] = translations

# %%
frequent_but_not_in_list
# Out:
#       word  frequency        pos  \
# 12    준비되다       3989  Noun Verb
# 37     조미료       1375       Noun
# 39      도덕       3016       Noun
# 44      크림       3399       Noun
# 52     시리즈       1229       Noun
# ...    ...        ...        ...
# 5407    때로       1059  Noun Josa
# 5426    비상       3959       Noun
# 5438    눈앞       1528       Noun
# 5440   생산력       2274       Noun
# 5456    정지       4049       Noun
#
#                                                      en
# 12                                be prepared; be ready
# 37                                  seasoning,condiment
# 39                               ethics,morals,morality
# 44                                         cream, cream
# 52                                               series
# ...                                                 ...
# 5407  sometimes,occasionally,at times,from time to t...
# 5426                                          emergency
# 5438
# 5440  productive capacity, production power, product...
# 5456  stop,halt,standstill,stop,halt,come to a stop[...
#
# [693 rows x 4 columns]

# %%
frequent_but_not_in_list.sort_values(by='frequency').to_csv('frequent_but_not_in_books.csv')

# %%
unified_df.to_pickle('all_words.pkl')
