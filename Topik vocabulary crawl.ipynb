# %%
import pandas as pd
import urllib3
from bs4 import BeautifulSoup

# %%
http = urllib3.PoolManager()
r = http.request('GET', 'https://trilingual.jp/jako/20190416-1632/')
soup = BeautifulSoup(r.data, 'lxml')

# %%
table = soup.find('table', attrs={'class': 'tablepress-id-7'})

# %%
def parse_table(table):
    table_body = table.find('tbody')
    data = []
    rows = table_body.find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele])
    return data

# %%
topik_level_1 = pd.DataFrame(parse_table(table), columns=['index', 'word', 'meaning'])

# %%
topik_level_1.head()
# Out:
#   index word      meaning
# 0     1   가게  store, shop
# 1     2   가격        price
# 2     3   가구    furniture
# 3     4  가깝다        close
# 4     5   가끔    sometimes

# %%
import os

# %%
SOURCE = 'memrise-scraper/memrise_scraper/'
for name in os.listdir(SOURCE):
    if os.path.isdir(SOURCE+name):
        d = []
        if 'summary.csv' not in os.listdir(SOURCE+name):    
            for filename in os.listdir(SOURCE+name):

                if filename[-4:] == '.csv':
                    print(os.path.join(SOURCE, name, filename))
                    df = pd.read_csv(os.path.join(SOURCE, name, filename), sep='\t', header=None)
                    if df.columns.__len__() != 2 : print(df.columns.__len__())
                    d.append(df)
            if len(d) > 0:
                df = pd.concat(d)
                df.to_csv(os.path.join(SOURCE, name, 'summary.csv'))

# %%
level_1 = ['"Sogang Korean New Series 1A" Vocabulary', 
           '"Sogang Korean New Series 1B" Vocabulary',
           'Integrated Korean Beginning 1', 
           'KIIP Beginner Level 1', 
           'Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어)', 
           'Fun Fun Korean 1', 
           '성균관어학 1급'
          ]

level_2 = ['Integrated Korean Beginning 2', 
           'KIIP Beginner Level 2',
           'Sogang Korean 2A Vocabulary',
           'Sogang Korean 2B (w', 
           'Yonsei Level 2 Vocabulary (연세 한국어 2급 단어)', 
           'Fun Fun Korean 2',
           '성균관 어학 2급'
          ]

level_3 = ['Sogang 3A vocabulary', 
           'Sogang Korean 3B (w',
           'Integrated Korean Intermediate 1', 
           'KIIP 중급1 (Level 3)',
           'Hanyang Workbook - 중급 1',
           'Yonsei 3-1 연세 한국어',
           'Yonsei 3-2 연세 한국어',
           '성균관어학 3급'
          ]

level_4 = ['Integrated Korean Intermediate 2 - First Edition', 
           'KIIP 2016 Level 4 ~ 중급2 NO TYPING', 
           'KIIP 4 - 2016',
           'Sogang 4A', 
           'Sogang 4B', 
           '한양대 중급2', 
           'Seoul National University Korean Level 4', 
           '연세 한국어 4-1 [Yonsei Korean 4-1]',
           'Yonsei Korean 4-2 (Units 6-10) + Proverbs',
           '가나다 intermediate 2',
           '서울대 한국어 4B',
           '성균관 어학 4급'
          ]

level_5 = ['KIIP Level 5 (new book 2016)', 
           '한양대 고급1', 
           'Ewha Korean 5', 
           '서울대 한국어 5A',
           '서울대 5B 한국어 교과서',
           '성균관 어학 5급'
          ]

level_6 = ['서울대 한국어 6A 교과서',
           '한양 고급2']

beginner = ['TOPIK Beginner Vocabulary List', 
            'Yonsei Korean Vocab Beginner', 
            '쏙쏙 40 days TOPIK 초급']

intermediate = ['Korean Vocabulary Practice (INTERMEDIATE)', 
                'TOPIK Essential Vocab 1000 (Intermediate)',
                'TOPIK in 30 Days+ Intermediate Vocabulary',
                'TOPIK 필수어위 1000 중급',
                '쏙쏙 TOPIK 한국어 어휘 중급 (day by day)',
                '2000 Essential Korean Words - Intermediate'
               ]

advanced = ['TOPIK Advanced Vocabulary',
            'Korean Vocabulary Practice for Foreigners Advanced', 
            'New TOPIK II 필수어휘 Vocabulary for Levels 5 & 6', 
            '토픽 어휘로 잡아라! [고급]',
            '한국어 TOPIK 어휘 고급 (50 days) advanced TOPIK vocab'
           ]

# %%
def find_source(filename):
    f = filename.lower()
    if 'sogang' in f:
        return 'sogang'
    elif 'yonsei' in f or '연세' in f:
        return 'yonsei'
    elif '한양' in f or 'hanyang' in f:
        return 'hanyang'
    elif '서울대' in f:
        return 'SNU'
    elif '성균관' in f:
        return 'sungkyunkwan'
    elif 'ewha' in f or '이화'in f:
        return 'ewha'
    elif 'kiip' in f:
        return 'kiip'
    elif 'integrated'in f:
        return 'integrated'
    elif 'topik' in f:
        return 'topik'
    else:
        return 'other'

# %%
frequencies = pd.read_csv('frequency_list.csv', index_col=0)

# %%
frequencies.head()
# Out:
#    word  frequency
# 0   일부러       1903
# 1  시작하다         80
# 2    잡지       1471
# 3   끼우다       2704
# 4    두께       3730

# %%
from wordfreq import zipf_frequency

# %%
def get_full_list(list_):
    d = []
    for filename in list_:
        df = pd.read_csv(os.path.join(SOURCE, filename, 'summary.csv'), index_col=0, names=['ko', 'en'], header=0)
        df['word_count'] = df['ko'].map(lambda x: x.split(' ').__len__())
        df['source'] = find_source(filename)
        df['filepath'] = filename
        df['zipf'] = df.ko.map(lambda x: zipf_frequency(x, 'ko'))
        df = pd.merge(df, frequencies, left_on='ko', right_on='word', how='left')
        d.append(df)
    return pd.concat(d)

# %%
def find_differences(level_1_vocabulary):
    categories = level_1_vocabulary.source.value_counts().index
    categories = sorted(categories)
    for source in categories:
        for source2 in categories:
            if source < source2:
                s = set(level_1_vocabulary[(level_1_vocabulary.source == source) & (level_1_vocabulary.word_count == 1)].ko.to_list())
                s2 = set(level_1_vocabulary[(level_1_vocabulary.source == source2) & (level_1_vocabulary.word_count == 1)].ko.to_list())
                print(source, 'und', source2)
                print('\tdifferent vocabulary', len(s.difference(s2)))
                print('\tsame vocabulary', len(s.intersection(s2)))

# %%
beginner_vocab = pd.concat([get_full_list(beginner), get_full_list(level_1), get_full_list(level_2)])
beginner_vocab['level'] = 'beginner'
beginner_vocab.sort_values(by='zipf', ascending=False).to_csv('beginner.csv')

# %%
intermediate_vocab = pd.concat([get_full_list(intermediate), get_full_list(level_3), get_full_list(level_4)])
intermediate_vocab['level'] = 'intermediate'
intermediate_vocab.sort_values(by='zipf', ascending=False).to_csv('intermediate.csv')

# %%
advanced_vocab = pd.concat([get_full_list(advanced), get_full_list(level_5), get_full_list(level_6)])
advanced_vocab['level'] = 'advanced'
advanced_vocab.sort_values(by='zipf', ascending=False).to_csv('advanced.csv')

# %%
all_vocab = pd.concat([beginner_vocab, intermediate_vocab, advanced_vocab])

# %%
single_word = all_vocab[(all_vocab.word_count == 1)]

# %%
import re

# %%
single_word.ko.map(lambda x: len(re.findall('[\W]', x)) > 0).value_counts()
# Out:
# False    42969
# True       253
# Name: ko, dtype: int64

# %%
single_word[~single_word.ko.map(lambda x: len(re.findall('[\W]', x)) > 0)].ko.value_counts()
# Out:
# 맡다      23
# 쓰다      22
# 바르다     20
# 싸다      20
# 걸리다     20
#         ..
# 외사촌      1
# 제기       1
# 건조증      1
# 청소년일     1
# 황하       1
# Name: ko, Length: 15291, dtype: int64

# %%
single_word = single_word[~single_word.ko.map(lambda x: len(re.findall('[\W]', x)) > 0)]

# %%
unified_df = single_word.groupby('ko').apply(lambda x: set(x.source.to_list())).reset_index(name='source')

# %%
unified_df = unified_df.merge(
    single_word.groupby('ko').apply(lambda x: list(set(x.en.to_list()))).reset_index(name='translation'),
    on='ko')

# %%
unified_df = unified_df.merge(
    single_word.groupby('ko').apply(lambda x: set(x.level.to_list())).reset_index(name='level'),
    on='ko')

# %%
unified_df = unified_df.merge(
    single_word.groupby('ko').apply(lambda x: set(x.filepath.to_list())).reset_index(name='memerisedeck'),
    on='ko')

# %%
unified_df = unified_df[unified_df.ko.map(lambda x: re.match('^[\d]*$', x) == None)]

# %%
unified_df[unified_df.level.map(lambda x: 'beginner' in x)]
# Out:
#           ko                                             source  \
# 4        1인실                                            {other}
# 6        1주일                                           {sogang}
# 7         1층                                           {yonsei}
# 20       5개월                                           {sogang}
# 24      AS센터                                            {other}
# ...      ...                                                ...
# 15273     흰색  {sogang, integrated, sungkyunkwan, other, hany...
# 15280      힘                             {other, yonsei, topik}
# 15284    힘내다                                     {topik, other}
# 15285    힘들다         {sungkyunkwan, other, yonsei, kiip, topik}
# 15286  힘들어하다                                            {other}
#
#                                              translation  \
# 4                                          [single room]
# 6                                             [one week]
# 7                                            [1st floor]
# 20                                         [five months]
# 24                          [after-sales service center]
# ...                                                  ...
# 15273                        [white, White, white color]
# 15280  [strength, energy, power (not 기...), Strength,...
# 15284                [to cheer up, pluck up one's heart]
# 15285  [to be tough, to be painful/tough, to be hard/...
# 15286                            [to have difficulty in]
#
#                           level  \
# 4                    {beginner}
# 6                    {beginner}
# 7                    {beginner}
# 20                   {beginner}
# 24                   {beginner}
# ...                         ...
# 15273  {intermediate, beginner}
# 15280  {intermediate, beginner}
# 15284  {intermediate, beginner}
# 15285                {beginner}
# 15286                {beginner}
#
#                                             memerisedeck
# 4                                     {Fun Fun Korean 2}
# 6                          {Sogang Korean 2A Vocabulary}
# 7       {Yonsei Korean 1 Vocabulary 2017 (연세 한국어 1급 단어)}
# 20                         {Sogang Korean 2A Vocabulary}
# 24                                    {Fun Fun Korean 2}
# ...                                                  ...
# 15273  {Hanyang Workbook - 중급 1, 성균관 어학 4급, Integrate...
# 15280  {Yonsei Korean Vocab Beginner, TOPIK in 30 Day...
# 15284  {쏙쏙 TOPIK 한국어 어휘 중급 (day by day), Fun Fun Kore...
# 15285  {Yonsei Korean Vocab Beginner, KIIP Beginner L...
# 15286                                 {Fun Fun Korean 2}
#
# [3166 rows x 5 columns]

# %%
unified_df[unified_df.level.map(lambda x: 'intermediate' in x)]
# Out:
#          ko                             source  \
# 2        1등                    {sogang, other}
# 3       1인당                     {yonsei, kiip}
# 5       1인용                           {sogang}
# 8       20쌍                             {kiip}
# 9      20인치                           {sogang}
# ...     ...                                ...
# 15282    힘껏              {sungkyunkwan, topik}
# 15284   힘내다                     {topik, other}
# 15287    힘듦                     {sungkyunkwan}
# 15288   힘쓰다  {topik, sungkyunkwan, SNU, other}
# 15290    힙합                            {other}
#
#                                              translation  \
# 2                                          [first place]
# 3                  [per person, each person, per capita]
# 5                                       [one person use]
# 8                               [20 pairs, couples (스물)]
# 9                                        [twenty inches]
# ...                                                  ...
# 15282  [With all the force one can  summon, with all ...
# 15284                [to cheer up, pluck up one's heart]
# 15287                                   [Laboriousness ]
# 15288   [to strive, try hard, strive, To make an effort]
# 15290                                          [hip-hop]
#
#                           level  \
# 2                {intermediate}
# 3                {intermediate}
# 5                {intermediate}
# 8                {intermediate}
# 9                {intermediate}
# ...                         ...
# 15282  {intermediate, advanced}
# 15284  {intermediate, beginner}
# 15287            {intermediate}
# 15288  {intermediate, advanced}
# 15290            {intermediate}
#
#                                             memerisedeck
# 2           {가나다 intermediate 2, Sogang Korean 3B (w}
# 3      {KIIP 2016 Level 4 ~ 중급2 NO TYPING, 연세 한국어 4-1...
# 5                                            {Sogang 4A}
# 8                                   {KIIP 중급1 (Level 3)}
# 9                                  {Sogang Korean 3B (w}
# ...                                                  ...
# 15282  {성균관 어학 5급, 쏙쏙 TOPIK 한국어 어휘 중급 (day by day), 한...
# 15284  {쏙쏙 TOPIK 한국어 어휘 중급 (day by day), Fun Fun Kore...
# 15287                                        {성균관 어학 4급}
# 15288  {TOPIK 필수어위 1000 중급, 서울대 5B 한국어 교과서, 쏙쏙 TOPIK ...
# 15290         {Seoul National University Korean Level 4}
#
# [9018 rows x 5 columns]

# %%
unified_df = unified_df.merge(frequencies, left_on='ko', right_on='word', how='left')
del unified_df['word']

# %%
unified_df['zipf'] = unified_df.ko.map(lambda x: zipf_frequency(x, 'ko'))

# %%
unified_df = unified_df.sort_values(by='zipf', ascending=False)

# %%
unified_df.head(20)
# Out:
#        ko                                             source  \
# 10326   이  {sogang, sungkyunkwan, other, integrated, yons...
# 10207   을                                          {hanyang}
# 9035    에                                       {integrated}
# 10190   은                                            {other}
# 934     고                                             {kiip}
# 2904    다         {sogang, other, integrated, yonsei, topik}
# 10255   의                 {yonsei, sungkyunkwan, integrated}
# 8846    어                        {sogang, other, integrated}
# 3401    도          {yonsei, sungkyunkwan, other, integrated}
# 3776    들                          {yonsei, SNU, integrated}
# 14238  하고                         {sungkyunkwan, integrated}
# 14336   한    {integrated, SNU, other, hanyang, yonsei, ewha}
# 14252  하다                  {yonsei, kiip, topik, integrated}
# 8404    아                                     {sungkyunkwan}
# 685     게                                            {topik}
# 2364    나          {yonsei, sungkyunkwan, topik, integrated}
# 12275   지                                            {topik}
# 14504   해              {yonsei, sogang, sungkyunkwan, topik}
# 10854  있다           {other, integrated, yonsei, kiip, topik}
# 515     거                                {topik, integrated}
#
#                                              translation  \
# 10326  [2, two (sino), 2 (Sino-Korean), this, Tooth, ...
# 10207                  [the weaker person in a contract]
# 9035   [in, at, on (indicates static location), to (d...
# 10190                                           [silver]
# 934    [put in front of someone's name to show they'v...
# 2904                   [all, all, everything (not 전...)]
# 10255     [of (particle), Possessive particle, dash (-)]
# 8846                                           [oh, oh!]
# 3401   [degree, also, too (particle), Too, also, a de...
# 3776                            [Field, plural particle]
# 14238                      [with, and (with nouns), And]
# 14336  [about, approximately (=약), resentment[sorrow ...
# 14252                       [to play, 낚시, 등산, 축구, to do]
# 8404                                            [Ah, oh]
# 685                                             [a crab]
# 2364                       [I (plain), I, me (informal)]
# 12275               [the time since, from the time when]
# 14504  [year, sun, the sun, harm/damage (verbs used: ...
# 10854  [To exist, to exist, to be, to have, to have, ...
# 515                 [thing (abbr.), thing (contraction)]
#
#                                     level  \
# 10326            {intermediate, beginner}
# 10207                          {advanced}
# 9035                           {beginner}
# 10190                      {intermediate}
# 934                            {advanced}
# 2904             {intermediate, beginner}
# 10255                          {beginner}
# 8846                           {beginner}
# 3401             {intermediate, beginner}
# 3776                 {beginner, advanced}
# 14238                          {beginner}
# 14336  {intermediate, beginner, advanced}
# 14252                          {beginner}
# 8404                           {beginner}
# 685                        {intermediate}
# 2364                           {beginner}
# 12275                      {intermediate}
# 14504            {intermediate, beginner}
# 10854                          {beginner}
# 515                            {beginner}
#
#                                             memerisedeck  frequency  zipf
# 10326  {성균관어학 3급, TOPIK in 30 Days+ Intermediate Voca...     5117.0  7.49
# 10207                                           {한양 고급2}        NaN  7.35
# 9035   {Integrated Korean Beginning 2, Integrated Kor...     2725.0  7.22
# 10190       {2000 Essential Korean Words - Intermediate}     4439.0  7.20
# 934                       {KIIP Level 5 (new book 2016)}        NaN  7.17
# 2904   {TOPIK in 30 Days+ Intermediate Vocabulary, Fu...     3271.0  7.11
# 10255  {Integrated Korean Beginning 1, 성균관어학 1급, Yons...        NaN  6.99
# 8846   {Integrated Korean Beginning 1, Sogang Korean ...      331.0  6.98
# 3401   {Integrated Korean Beginning 1, 2000 Essential...     2972.0  6.98
# 3776   {Integrated Korean Beginning 1, 서울대 한국어 6A 교과서...     2243.0  6.96
# 14238          {Integrated Korean Beginning 1, 성균관어학 1급}        NaN  6.94
# 14336  {Ewha Korean 5, 한양대 고급1, 서울대 한국어 4B, Yonsei Le...     2922.0  6.91
# 14252  {Yonsei Korean Vocab Beginner, 쏙쏙 40 days TOPI...        1.0  6.91
# 8404                                          {성균관어학 1급}      217.0  6.90
# 685          {TOPIK in 30 Days+ Intermediate Vocabulary}     3547.0  6.90
# 2364   {TOPIK Beginner Vocabulary List, Integrated Ko...        4.0  6.89
# 12275        {TOPIK in 30 Days+ Intermediate Vocabulary}      527.0  6.87
# 14504  {Yonsei Korean Vocab Beginner, 쏙쏙 40 days TOPI...     5052.0  6.82
# 10854  {Yonsei Korean Vocab Beginner, KIIP Beginner L...        2.0  6.77
# 515    {TOPIK Beginner Vocabulary List, Integrated Ko...     2480.0  6.75

# %%
ad = unified_df[unified_df.level.map(lambda x: 'advanced' in x)].sort_values(by='frequency')

# %%
ad.to_json('advanced.json')

# %%
ad[ad.source.map(len) > 3]
# Out:
#           ko                                             source  \
# 3317     대하다              {topik, sungkyunkwan, other, hanyang}
# 6544      사회  {sogang, sungkyunkwan, other, integrated, yons...
# 848       경우  {sungkyunkwan, other, hanyang, yonsei, kiip, t...
# 7908      시대      {sungkyunkwan, other, hanyang, yonsei, topik}
# 9839      운동        {integrated, other, hanyang, yonsei, topik}
# ...      ...                                                ...
# 3956   뛰쳐나가다             {sogang, sungkyunkwan, topik, hanyang}
# 11157   장바구니                   {SNU, other, ewha, yonsei, kiip}
# 11151    장마철                {sogang, SNU, other, yonsei, topik}
# 4292    매콤하다        {sogang, sungkyunkwan, SNU, hanyang, topik}
# 11281   저렴하다  {sogang, sungkyunkwan, SNU, other, hanyang, to...
#
#                                              translation  \
# 3317   [to treat, address, receive (not 여...), To dea...
# 6544   [society, community (society), society, the co...
# 848    [a case, case, circumstances that have set sta...
# 7908   [a time period, Era, age, an era, era, period,...
# 9839   [exercise (sport), movement, campaign, exercis...
# ...                                                  ...
# 3956   [To storm out, run out, dash out, storm out, t...
# 11157  [shopping bag, a shopping cart; a shopping bas...
# 11151  [monsoon season, rainy season, the rainy seaso...
# 4292   [spicy, to be moderately spicy, To be spicy an...
# 11281  [To be cheap, inexpensive, to be cheap; inexpe...
#
#                                     level  \
# 3317   {intermediate, beginner, advanced}
# 6544             {intermediate, advanced}
# 848              {intermediate, advanced}
# 7908             {intermediate, advanced}
# 9839   {intermediate, beginner, advanced}
# ...                                   ...
# 3956             {intermediate, advanced}
# 11157            {intermediate, advanced}
# 11151  {intermediate, beginner, advanced}
# 4292             {intermediate, advanced}
# 11281            {intermediate, advanced}
#
#                                             memerisedeck  frequency  zipf
# 3317   {TOPIK in 30 Days+ Intermediate Vocabulary, 한양...       10.0  4.63
# 6544   {TOPIK Essential Vocab 1000 (Intermediate), TO...       19.0  5.17
# 848    {Seoul National University Korean Level 4, TOP...       38.0  5.20
# 7908   {TOPIK in 30 Days+ Intermediate Vocabulary, Ha...       69.0  5.12
# 9839   {Yonsei Korean Vocab Beginner, TOPIK in 30 Day...       76.0  5.19
# ...                                                  ...        ...   ...
# 3956   {Sogang 4A, TOPIK in 30 Days+ Intermediate Voc...        NaN  0.00
# 11157  {KIIP 4 - 2016, Yonsei 3-1 연세 한국어, KIIP 2016 L...        NaN  0.00
# 11151  {Yonsei 3-2 연세 한국어, 서울대 5B 한국어 교과서, 쏙쏙 40 days...        NaN  0.00
# 4292   {성균관어학 3급, 서울대 5B 한국어 교과서, 한양대 중급2, 쏙쏙 TOPIK 한...        NaN  0.00
# 11281  {Sogang 4A, 성균관어학 3급, Seoul National Universit...        NaN  0.00
#
# [1556 rows x 7 columns]
